# %%
from mrcnn.config import Config
from mrcnn import model as modellib
from mrcnn import visualize
import numpy as np
import colorsys
import argparse
import imutils
import random
import cv2
import os
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Loading all the classnames from a file(80 classes)

# %%
CLASS_NAMES = open(r'C:\Users\Manikanta Punnam\coursera\Notebooks\Convolutional Neural Networks\keras-mask-rcnn\keras-mask-rcnn'+'/coco_labels.txt').read().strip().split("\n")

# %%
class SimpleConfig(Config):
    # give the configuration a recognizable name
    NAME = "coco_inference"
    # set the number of GPUs to use along with the number of images
    # per GPU
    GPU_COUNT = 1
    IMAGES_PER_GPU = 1
    # number of classes (we would normally add +1 for the background
    # but the background class is *already* included in the class
    # names)
    NUM_CLASSES = len(CLASS_NAMES)

# %%
# initialize the inference configuration
config = SimpleConfig()
# initialize the Mask R-CNN model for inference and then load the
# weights
print("[INFO] loading Mask R-CNN model...")
model = modellib.MaskRCNN(mode="inference", config=config,model_dir=os.getcwd())
model.load_weights(r'C:\Users\Manikanta Punnam\coursera\Notebooks\Convolutional Neural Networks\keras-mask-rcnn\keras-mask-rcnn'+'/mask_rcnn_coco.h5', by_name=True)
# Out:
# [INFO] loading Mask R-CNN model...
# WARNING:tensorflow:From C:\Users\Manikanta Punnam\coursera\Notebooks\Convolutional Neural Networks\Mask_RCNN\mrcnn\model.py:772: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.

# %%
# load the input image, convert it from BGR to RGB channel
# ordering, and resize the image
image = cv2.imread(r'C:\Users\Manikanta Punnam\coursera\Notebooks\Convolutional Neural Networks'+'/foreground_test_13.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
#image = imutils.resize(image, width=150)
# perform a forward pass of the network to obtain the results
print("[INFO] making predictions with Mask R-CNN...")
r = model.detect([image], verbose=1)[0]
# Out:
# [INFO] making predictions with Mask R-CNN...
# Processing 1 images
# image                    shape: (573, 860, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  146.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32

# %% [markdown]
# ## Trying this algorithm with a sample image

# %%
import time
stime = time.time()
indices = np.argsort(r['scores'])[::-1]
for i in indices:
    classID = r["class_ids"][i]
    if(classID == 1):
        score = r['scores'][i]
        if(score > 0.5):
            mask = r["masks"][:, :, i]
            mask = mask.astype('uint8')
            image_bgr = cv2.cvtColor(image,cv2.COLOR_RGB2BGR)
            blur_image = cv2.GaussianBlur(image_bgr,(41,41),0)
            blur_image_rgb = cv2.cvtColor(blur_image,cv2.COLOR_BGR2RGB)
            mask_1 = np.expand_dims(mask,axis=2)
            outputMask = np.concatenate((mask_1,mask_1,mask_1),axis=-1)
            output_image = np.where((outputMask==0),blur_image_rgb,image)
            plt.imshow(output_image)
        else:
            print('no output')
        break
print(time.time()-stime)
# Out:
# 0.06685066223144531

# %% [markdown]
# ## This function contains the core part of this algorithm.

# %%
def extract_foreground(image):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # converting from bgr rgb
    image = imutils.resize(image, width=512) # resizing to a particular shape , so this satisfies the Mask R-CNN requirements.
    # perform a forward pass of the network to obtain the results
    print("[INFO] making predictions with Mask R-CNN...")
    r = model.detect([image], verbose=1)[0]
    indices = np.argsort(r['scores'])[::-1] #sorting detected objects based on probability they get.
    for i in indices:
        classID = r["class_ids"][i] # getting the class id (1 means person)
        if(classID == 1):
            score = r['scores'][i]
            if(score > 0.5): #checking if the detected object satisfies the given threshold.Here we want only the closest person,whenever we get the closest person, we will quit from this loop.
                mask = r["masks"][:, :, i] # taking the mask of corresponding object.
                mask = mask.astype('uint8')
                image_bgr = cv2.cvtColor(image,cv2.COLOR_RGB2BGR)
                blur_image = cv2.GaussianBlur(image_bgr,(41,41),0) # creating a blur image of original image.
                mask_1 = np.expand_dims(mask,axis=2)
                outputMask = np.concatenate((mask_1,mask_1,mask_1),axis=-1) # creating a 3-dimensional mask to satisfies this condition below.
                output_image = np.where((outputMask==0),blur_image,image_bgr) #overlaying detected object onto the blurred image using mask.
                return output_image,True #returning resulting image.
            else:
                return None,False # returning False in case if the closest person object is not found.

# %% [markdown]
# ## Using this application on WebCam

# %%
cap = cv2.VideoCapture(0) # opening a web cam
frame_width = int(cap.get(3)) #getting the width and height of the frame in a webcam.
frame_height = int(cap.get(4))
size = (frame_width, frame_height)   
result = cv2.VideoWriter('sample_video.avi',  
                         cv2.VideoWriter_fourcc(*'MJPG'), 
                         10, size) # creating a video writer object to store every frame into a video file
while cap.isOpened():
    ret,frame = cap.read() # reading frame from webcam.
    cv2.imshow('Video',frame) #showing this frame to us in webcam.
    result.write(frame) # write each frame to a video file.
    if(cv2.waitKey(1) & 0xFF == 27): #press ESC to escape from video capturing.
        break
cap.release()
cv2.destroyAllWindows()
result.release()

# %% [markdown]
# ## Using this Application on a recorded video

# %%
cap = cv2.VideoCapture('sample_video_to_extract_foreground.mp4') #Opening a recorded video.
frame_width = int(cap.get(3)) # getting the frame size of this video
frame_height = int(cap.get(4))
size = (frame_width, frame_height)   
result = cv2.VideoWriter('blurring_background_output2.avi',  
                         cv2.VideoWriter_fourcc(*'MJPG'), 
                         10, size)
while cap.isOpened():
    ret,frame = cap.read()
    if(ret == True):
        h,w = frame.shape[:2]
        output,found = extract_foreground(frame)
        if(found == False): # if there is no closest person object detected, then store the original frame into video file.
            output = frame
        else:
            output = cv2.resize(output,(w,h)) # resizing the output image size to the size of original frame.
        result.write(output)
    else:
        break
    if(cv2.waitKey(1) & 0XFF == 27):
        break
cv2.destroyAllWindows()
cap.release()
# Out:
# [INFO] making predictions with Mask R-CNN...
# Processing 1 images
# image                    shape: (288, 512, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# [INFO] making predictions with Mask R-CNN...
# Processing 1 images
# image                    shape: (288, 512, 3)         min:    1.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# [INFO] making predictions with Mask R-CNN...
# Processing 1 images
# ...

# %% [markdown]
# ## This is an other method to overlay the detected object onto blurred image, but it doesn't make much difference in performance.

# %%
'''stime = time.time()
indices = np.argsort(r['scores'])[::-1]
for i in indices:
    classID = r["class_ids"][i]
    if(classID == 1):
        score = r['scores'][i]
        if(score > 0.5):
            (startY,startX,endY,endX) = r['rois'][i]
            mask = r["masks"][:, :, i]
            mask = mask.astype('uint8')
            mask = mask[startY:endY,startX:endX]
            image_bgr = cv2.cvtColor(image,cv2.COLOR_RGB2BGR)
            blur_image = cv2.GaussianBlur(image_bgr,(41,41),0)
            blur_image_rgb = cv2.cvtColor(blur_image,cv2.COLOR_BGR2RGB)
            mask_1 = np.expand_dims(mask,axis=2)
            outputMask = np.concatenate((mask_1,mask_1,mask_1),axis=-1)
            blur_image_rgb[startY:endY,startX:endX] = np.where((outputMask==0),blur_image_rgb[startY:endY,startX:endX],image[startY:endY,startX:endX])
            plt.imshow(blur_image_rgb)
        else:
            print('no output')
        break
print(time.time()-stime)'''
# Out:
# 0.06588149070739746

# %% [markdown]
# ## Conclusion:
#         1. The main objective of this algorithm is to detect the person who is talking in front of webcam an then blur the background around this person in a video calling.
#         2. It will be useful if the user wants the privacy (not their family members or friends be visible to others in that video conference)
#         3.So Video Conference attendees can concentrate only on the person who is facing this video conference either side.
